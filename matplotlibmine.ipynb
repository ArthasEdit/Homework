# %%
#simple

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

s = pd.Series([1, 2, 3, 5, 7, 9])
fig, ax = plt.subplots()
s.plot.bar()
plt.title('ArthasEdit')
fig.savefig('my_plot.png')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math


# Fixing random state for reproducibility
np.random.seed(19680801)

plt.style.use('bmh')


def plot_beta_hist(ax, a, b):
    ax.hist(np.random.beta(a, b, size=10000),
            histtype="stepfilled", bins=25, alpha=0.8, density=True)


fig, ax = plt.subplots()
plot_beta_hist(ax, 1, 10)
plot_beta_hist(ax, 6, 12)
plot_beta_hist(ax, 12, 6)
plot_beta_hist(ax, 10, 1)
ax.set_title("learning python matplotlib @ArthasEdit")

plt.show()

# %%
from cycler import cycler
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Define a list of markevery cases and color cases to plot
cases = [None,
        8,
        8,
        8,
        8,
        8, 
        8,
        8,
        8,
        8,
        8,]

colors = ['#1f77b4',
          '#ff7f0e',
          '#2ca02c',
          '#d62728',
          '#9467bd',
          '#8c564b',
          '#e377c2',
          '#7f7f7f',
          '#bcbd22',
          '#17becf',
          '#1a55FF']

# Configure rcParams axes.prop_cycle to simultaneously cycle cases and colors.
mpl.rcParams['axes.prop_cycle'] = cycler(markevery=cases, color=colors)

# Create data points and offsets
x = np.linspace(-10, math.cos(2) * np.pi) #1st value define density; 2nd value how many times should be curve
offsets = np.linspace(.1, math.cos(2) * np.pi, 11, endpoint=False)
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# Set the plot curve with markers and a title
fig = plt.figure()
ax = fig.add_axes([.5, .3, math.sin(1)**2, .29])#3rd value define lenght of figure; 4th value define hight of figure

for i in range(len(cases)):
    ax.plot(yy[:, i], marker='o', label=str(cases[i]))
    ax.legend(bbox_to_anchor=(1.05, 1.01), loc='upper left', borderaxespad=1)#1st value define x 2nd value define y

plt.title("learning python matplotlib @ArthasEdit")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# Fixing random state for reproducibility
np.random.seed(1555)

# unit area ellipse
rx, ry = 3., 3.
area = rx * ry * np.pi
theta = np.arange(0, 2**6 * np.pi + 1, .1)
verts = np.column_stack([rx / area * np.sin(theta), ry / area * np.sin(theta)])

x, y, s, c = np.random.rand(4, 500)
s *= 10**2.

fig, ax = plt.subplots()
ax.scatter(x, y, s, c, marker=verts)

plt.title("learning python matplotlib @ArthasEdit")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(14)
y = np.sin(x / 2)

plt.plot(x, y + 2, drawstyle='steps', label='pre (default)') #we can use also drawstyle='steps' instead of plt.steps
plt.plot(x, y + 2, 'o--', color='grey', alpha=0.3)

plt.step(x, y + 1, where='mid', label='mid')
plt.plot(x, y + 1, 'o--', color='grey', alpha=0.3)

plt.step(x, y, where='post', label='post')
plt.plot(x, y, 'x--', color='grey', alpha=0.5)

plt.grid(axis='x', color='0.95')
plt.legend(title='Parameter where:')
plt.title('"learning python matplotlib @ArthasEdit"')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as mp

plt.figure(figsize=(8, 8),dpi = 250)

Z1 = np.add.outer(range(8), range(8)) % 2  # chessboard
im1 = plt.imshow(Z1, cmap=plt.cm.gray, extent=extent)

plt.grid(False)

#Z2 = func3(X, Y)

#im2 = plt.imshow(Z2, cmap=plt.cm.viridis, alpha=0, extent=extent)


plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.subplot(projection="aitoff") #there 4 value of projection for globus: aitoff, hammer, lambert, mollweide. it is only draw ellipse shape circle
plt.title("@ArthasEdit")
plt.grid(True, color='darkblue')

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Google')
rects2 = ax.bar(x + width/2, women_means, width, label='Yandex')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(np.cos(10), .4 * np.pi, 19999)
y = np.exp(np.sin(x))

plt.xticks([1, 2], size=20)
plt.yticks([1, 2], size=20)

plt.stem(x, y)
plt.show()
